# %% [markdown]
# Import necessary libraries:

# %%
import json
import os
import copy
from metadataSchemaReader import MetadataSchemaReader
from attributeMapping import AttributeMapping
import datetime as dt
from dateutil import parser
import logging

# view all the metadata stored in the ZEISS TIFF file
# from https://github.com/ks00x/zeiss_tiff_meta.git
import zeiss_tiff_meta.zeisstiffmeta as zm

# %% [markdown]
# Read in source image and extract metadata using zeiss method:

# %%
src = 'FeMoOx_AntiA_04_1k5x_CN.tif' # Read in source image
tab = zm.zeiss_meta(src)            # Extract the full metadata

# %% [markdown]
# Clean up the metadata:

# %%
del tab[0] # delete first result as it is useless

# 
resultDictionary = {**dict((x1+"_value",x2) for x0, x1, x2, x3 in tab) , **dict((x1+"_unit",x3) for x0, x1, x2, x3 in tab)}
resultDictionary_filtered={k: v for k, v in resultDictionary.items() if v != ''}
resultDictionary_filtered_sorted=dict(sorted(resultDictionary_filtered.items()))
resultDictionary = dict((x1, {"value":x2,"unit":x3}) for x0, x1, x2, x3 in tab)
# resultDictionary_filtered_sorted['Store resolution_value'].split('*')
resultDictionary_filtered_sorted
# Out:
# {'ASAP DFE1 Minus5V Analogue_unit': 'V',
#  'ASAP DFE1 Minus5V Analogue_value': 0.0,
#  'ASAP DFE1 Plus5V Analogue_unit': 'V',
#  'ASAP DFE1 Plus5V Analogue_value': 0.0,
#  'ASAP DFE1 Plus5V Digital_unit': 'V',
#  'ASAP DFE1 Plus5V Digital_value': 0.0,
#  'ASAP DFE1 Temperature_unit': '°C',
#  'ASAP DFE1 Temperature_value': 0.0,
#  'ASAP DFE2 Minus5V Analogue_unit': 'V',
#  'ASAP DFE2 Minus5V Analogue_value': 0.0,
#  'ASAP DFE2 Plus5V Analogue_unit': 'V',
#  'ASAP DFE2 Plus5V Analogue_value': 0.0,
#  'ASAP DFE2 Plus5V Digital_unit': 'V',
#  'ASAP DFE2 Plus5V Digital_value': 0.0,
#  'ASAP DFE2 Temperature_unit': '°C',
#  'ASAP DFE2 Temperature_value': 0.0,
#  'ASAP DFE3 Minus5V Analogue_unit': 'V',
#  'ASAP DFE3 Minus5V Analogue_value': 0.0,
#  'ASAP DFE3 Plus5V Analogue_unit': 'V',
#  'ASAP DFE3 Plus5V Analogue_value': 0.0,
#  'ASAP DFE3 Plus5V Digital_unit': 'V',
#  'ASAP DFE3 Plus5V Digital_value': 0.0,
#  'ASAP DFE3 Temperature_unit': '°C',
#  'ASAP DFE3 Temperature_value': 0.0,
#  'ASAP DFE4 Minus5V Analogue_unit': 'V',
#  'ASAP DFE4 Minus5V Analogue_value': 0.0,
#  'ASAP DFE4 Plus5V Analogue_unit': 'V',
#  'ASAP DFE4 Plus5V Analogue_value': 0.0,
#  'ASAP DFE4 Plus5V Digital_unit': 'V',
#  'ASAP DFE4 Plus5V Digital_value': 0.0,
#  'ASAP DFE4 Temperature_unit': '°C',
#  'ASAP DFE4 Temperature_value': 0.0,
#  'ASAP MB Temperature_unit': '°C',
#  'ASAP MB Temperature_value': 0.0,
#  'ASAP VBE1 Minus5V Analogue_unit': 'V',
#  'ASAP VBE1 Minus5V Analogue_value': 0.0,
#  'ASAP VBE1 Plus5V Analogue_unit': 'V',
#  'ASAP VBE1 Plus5V Analogue_value': 0.0,
#  'ASAP VBE1 Temperature_unit': '°C',
#  'ASAP VBE1 Temperature_value': 0.0,
#  'ASAP VBE2 Minus5V Analogue_unit': 'V',
#  'ASAP VBE2 Minus5V Analogue_value': 0.0,
#  'ASAP VBE2 Plus5V Analogue_unit': 'V',
#  'ASAP VBE2 Plus5V Analogue_value': 0.0,
#  'ASAP VBE2 Temperature_unit': '°C',
#  'ASAP VBE2 Temperature_value': 0.0,
#  'Aa 1_unit': '°',
#  'Aa 1_value': 0.0,
#  'Aa 2_unit': '°',
#  'Aa 2_value': 0.0,
#  'Aa 3_unit': 'kV',
#  'Aa 3_value': 0.0,
#  'Aa 4_unit': 'kV',
#  'Aa 4_value': 0.0,
#  'Align 1 X_unit': '%',
#  'Align 1 X_value': 0.0,
#  'Align 1 Y_unit': '%',
#  'Align 1 Y_value': 0.0,
#  'All Frozen_value': True,
#  'All Zones_value': False,
#  'Anode Aperture Changer_value': 'Absent',
#  'Anode Spacer_value': 'High KV',
#  'Aperture Align X_unit': '%',
#  'Aperture Align X_value': 20.1,
#  'Aperture Align Y_unit': '%',
#  'Aperture Align Y_value': -14.9,
#  'Aperture No._value': 5,
#  'Aperture Posn X_unit': 'mm',
#  'Aperture Posn X_value': 5.0,
#  'Aperture Posn Y_unit': 'mm',
#  'Aperture Posn Y_value': 1.0,
#  'Aperture Size_unit': 'µm',
#  'Aperture Size_value': 120.0,
#  'Aperture at X_unit': '%',
#  'Aperture at X_value': -15.5,
#  'Aperture at Y_unit': '%',
#  'Aperture at Y_value': 60.1,
#  'Aperture value at FishEye X_unit': '%',
#  'Aperture value at FishEye X_value': 0.0,
#  'Aperture value at FishEye Y_unit': '%',
#  'Aperture value at FishEye Y_value': 0.0,
#  'Aperture_value': 'Clean',
#  'Area Fraction_unit': '%',
#  'Area Fraction_value': 0.0,
#  'Argon Acc I is_unit': 'µA',
#  'Argon Acc I is_value': 0.0,
#  'Argon Beam Shift X_unit': 'nm',
#  'Argon Beam Shift X_value': 0.0,
#  'Argon Beam Shift Y_unit': 'nm',
#  'Argon Beam Shift Y_value': 0.0,
#  'Argon Column Angle_unit': '°',
#  'Argon Column Angle_value': 0.0,
#  'Argon Condenser is_unit': 'V',
#  'Argon Condenser is_value': 0,
#  'Argon Condenser_unit': 'V',
#  'Argon Condenser_value': 0,
#  'Argon Discharge I is_unit': 'µA',
#  'Argon Discharge I is_value': 0.0,
#  'Argon Discharge is_unit': 'V',
#  'Argon Discharge is_value': 0,
#  'Argon Discharge_unit': 'V',
#  'Argon Discharge_value': 0,
#  'Argon Energy is_unit': 'V',
#  'Argon Energy is_value': 0,
#  'Argon Energy_unit': 'V',
#  'Argon Energy_value': 0,
#  'Argon Extractor is_unit': 'V',
#  'Argon Extractor is_value': 0,
#  'Argon Extractor_unit': 'V',
#  'Argon Extractor_value': 0,
#  'Argon Gas Flow is_unit': '%',
#  'Argon Gas Flow is_value': 0.0,
#  'Argon Gas Flow_unit': '%',
#  'Argon Gas Flow_value': 0.0,
#  'Argon Gun is_value': False,
#  'Argon Gun_value': 'Absent',
#  'Argon MFC Valve_value': 'Closed',
#  'Argon Mag Factor_unit': 'nm',
#  'Argon Mag Factor_value': 0.0,
#  'Argon Magnification_unit': 'X',
#  'Argon Magnification_value': 0,
#  'Argon Mill Progress_unit': '%',
#  'Argon Mill Progress_value': 0.0,
#  'Argon Mill_value': False,
#  'Argon Objective is_unit': 'V',
#  'Argon Objective is_value': 0,
#  'Argon Objective_unit': 'V',
#  'Argon Objective_value': 0,
#  'Argon Pixel Size_unit': 'fm',
#  'Argon Pixel Size_value': 0.0,
#  'Argon Scan_value': False,
#  'Argon Shift Ratio X_value': 0.0,
#  'Argon Shift Ratio Y_value': 0.0,
#  'Argon V Int is_unit': 'V',
#  'Argon V Int is_value': 0,
#  'Argon V Int_unit': 'V',
#  'Argon V Int_value': 0,
#  'Argon XY Ratio_value': 0.0,
#  'Auto B Target_unit': '%',
#  'Auto B Target_value': 49.8,
#  'Auto BC_value': False,
#  'Auto C Target_unit': '%',
#  'Auto C Target_value': 23.6,
#  'BGPL_unit': 'mm',
#  'BGPL_value': 10.0,
#  'BSD Auto Range_value': True,
#  'BSD Autolevel Mode_value': 'Normal',
#  'BSD Bandwidth_value': 'DC',
#  'BSD Fast Scan_value': False,
#  'BSD Fast_value': False,
#  'BSD Gain_value': 'High',
#  'BSD Invert_value': False,
#  'BSD Mode_value': 'Compo',
#  'BSD_value': 'Present',
#  'Back Grid_unit': 'V',
#  'Back Grid_value': 0,
#  'Beam Blanked Aperture Pos X_unit': '%',
#  'Beam Blanked Aperture Pos X_value': 100.0,
#  'Beam Blanked Aperture Pos Y_unit': '%',
#  'Beam Blanked Aperture Pos Y_value': 100.0,
#  'Beam Blanked Gun Pos X_unit': '%',
#  'Beam Blanked Gun Pos X_value': 100.0,
#  'Beam Blanked Gun Pos Y_unit': '%',
#  'Beam Blanked Gun Pos Y_value': 100.0,
#  'Beam Blanked_value': True,
#  'Beam Blanker Mode_value': 'Blanked',
#  'Beam Current_unit': 'µA',
#  'Beam Current_value': 80.0,
#  'Beam Offset X_unit': 'µm',
#  'Beam Offset X_value': 17.97,
#  'Beam Offset Y_unit': 'µm',
#  'Beam Offset Y_value': -77.87,
#  'Beam Shift Align X_unit': 'nm',
#  'Beam Shift Align X_value': 0.0,
#  'Beam Shift Align Y_unit': 'nm',
#  'Beam Shift Align Y_value': 0.0,
#  'Beam Shift X_unit': '%',
#  'Beam Shift X_value': 11.9,
#  'Beam Shift Y_unit': '%',
#  'Beam Shift Y_value': -50.4,
#  'Beam State_value': 'Beam On',
#  'Beam Time_unit': 'Hours',
#  'Beam Time_value': 14501.86,
#  'Beam deceleration Volts_unit': 'V',
#  'Beam deceleration Volts_value': 0,
#  'Beam deceleration carousel_value': False,
#  'Beam deceleration_value': False,
#  'Beam sleeve Bias_unit': 'V',
#  'Beam sleeve Bias_value': 0,
#  'Beam sleeve fitted_value': False,
#  'Beam sleeve_value': 'Out',
#  'Best Aperture_value': True,
#  'Black Threshold_unit': '%',
#  'Black Threshold_value': 0.0,
#  'Brightness A_unit': '%',
#  'Brightness A_value': 51.0,
#  'Brightness B_unit': '%',
#  'Brightness B_value': 65.6,
#  'Brightness C_unit': '%',
#  'Brightness C_value': 65.6,
#  'Brightness D_unit': '%',
#  'Brightness D_value': 65.6,
#  'Brightness_unit': '%',
#  'Brightness_value': 51.0,
#  'C.L.S.Valve_value': 'Closed',
#  'C1 Cal_value': 0.958,
#  'C1 Lens I_unit': 'µA',
#  'C1 Lens I_value': 0,
#  'C1 Rem_value': 0.0105,
#  'C2 Cal_value': 1.063,
#  'C2 Lens I_unit': 'µA',
#  'C2 Lens I_value': 0,
#  'C2 Rem_value': 0.0318,
#  'C3 Cal_value': 0.939,
#  'C3 Lens I_unit': 'mA',
#  'C3 Lens I_value': 925.39,
#  'C3 Rem_value': 0.0137,
#  'C3 Reversal_value': 'Normal',
#  'C3 Rot Corrn._value': True,
#  'C3 Rotn Sign_value': '+',
#  'C3 saved for beam decel_unit': 'µA',
#  'C3 saved for beam decel_value': 0,
#  'CC Pressure_unit': '%',
#  'CC Pressure_value': 0.0,
#  'CC Status_value': False,
#  'CC Type_value': 'On GIS',
#  'CCD Illum._unit': '%',
#  'CCD Illum._value': 47.0,
#  'Cal Mode_value': False,
#  'Calibrate Mag Base_value': 50000.0,
#  'Calibrate Mag Lower X_value': 0.0,
#  'Calibrate Mag Lower Y_value': 0.0,
#  'Calibrate Mag Upper X_value': 0.0,
#  'Calibrate Mag Upper Y_value': 0.0,
#  'Calibration_value': 'Disabled',
#  'Chamber Pressure Detailed_unit': 'Pa',
#  'Chamber Pressure Detailed_value': 0.0,
#  'Chamber Status_value': 'Power Up',
#  'Chamber_unit': 'Pa',
#  'Chamber_value': 0.0,
#  'Channels_value': 1,
#  'Clip Limit_value': 0,
#  'Collector Bias_unit': 'V',
#  'Collector Bias_value': 300,
#  'Collector Voltage_unit': 'kV',
#  'Collector Voltage_value': -4.0,
#  'Colour Mode_value': False,
#  'Column Chamber valve_value': 'Open',
#  'Column Isolated_value': False,
#  'Column Mode_value': 'High Resolution',
#  'Column pumping_value': 'Ready',
#  'Column_value': '1500XB',
#  'Compu. Height_unit': 'mm',
#  'Compu. Height_value': -1.358,
#  'Compu. Tilt Error_value': 1.703,
#  'Compu. Tilt Offset_unit': 'mm',
#  'Compu. Tilt Offset_value': 0.0,
#  'Compuc. Mode_value': 'Rotate',
#  'Condenser Normal_value': 'Normal',
#  'Condenser Reversed_value': False,
#  'Conjugate posn._unit': 'mm',
#  'Conjugate posn._value': -164.0,
#  'Contrast A_unit': '%',
#  'Contrast A_value': 19.7,
#  'Contrast B_unit': '%',
#  'Contrast B_value': 63.2,
#  'Contrast C_unit': '%',
#  'Contrast C_value': 63.2,
#  'Contrast D_unit': '%',
#  'Contrast D_value': 63.2,
#  'Contrast Enhanced_value': False,
#  'Contrast_unit': '%',
#  'Contrast_value': 19.7,
#  'Control_value': 'Signal A',
#  'Convertor Voltage_unit': 'kV',
#  'Convertor Voltage_value': 0.0,
#  'CoolStage Type_value': 'Cold',
#  'Crosshairs_value': False,
#  'Cursor Height_unit': 'µm',
#  'Cursor Height_value': 23.0,
#  'Cursor Width_unit': 'nm',
#  'Cursor Width_value': 0.0,
#  'Custom Holder_value': False,
#  'Cycle Time_unit': 'Mins',
#  'Cycle Time_value': 1.6,
#  'Da 1_unit': 'nm',
#  'Da 1_value': 0.0,
#  'Da 2_unit': 'nm',
#  'Da 2_value': 0.0,
#  'Da 3_unit': 'nm',
#  'Da 3_value': 0.0,
#  'Da 4_unit': 'nm',
#  'Da 4_value': 0.0,
#  'Date_value': '13 Jul 2021',
#  'Db 1_unit': 'nm²',
#  'Db 1_value': 0.0,
#  'Db 2_unit': 'nm²',
#  'Db 2_value': 0.0,
#  'Db 3_unit': 'nm²',
#  'Db 3_value': 0.0,
#  'Db 4_unit': 'nm²',
#  'Db 4_value': 0.0,
#  'Decl cal 1_value': 0.0,
#  'Decl cal 2_value': 1.0,
#  'Defect ID_value': 0,
#  'Det BW Offset_value': 0,
#  'Detector_value': 'InLens',
#  'Display LUT mode_value': 'Normal',
#  'Display_value': 0,
#  'Double Deflection State_value': False,
#  'Drift Max Tries_value': 10,
#  'Drift Max.Pix.Error_value': 1,
#  'Drift Min Conf_unit': '%',
#  'Drift Min Conf_value': 50.0,
#  'Dual Mag Gain X_value': 670.0,
#  'Dual Mag Gain Y_value': 670.0,
#  'Dual Mag Offset X_value': 0.0,
#  'Dual Mag Offset Y_value': 0.0,
#  'Dual Monitor_value': False,
#  'Dwell Time_unit': 'ns',
#  'Dwell Time_value': 100,
#  'Dyn.Focus_value': False,
#  'EHT Cal@0.1KV_unit': 'V',
#  'EHT Cal@0.1KV_value': 113,
#  'EHT Cal@10KV_unit': 'kV',
#  'EHT Cal@10KV_value': 10.06,
#  'EHT Cal@24KV_unit': 'kV',
#  'EHT Cal@24KV_value': 24.12,
#  'EHT Cal@30KV_unit': 'kV',
#  'EHT Cal@30KV_value': 30.14,
#  'EHT Comms Fail_value': False,
#  'EHT Set minimum_unit': 'kV',
#  'EHT Set minimum_value': 0.01,
#  'EHT Target_unit': 'kV',
#  'EHT Target_value': 5.0,
#  'EHT Vac ready_value': True,
#  'EHT set maximum_unit': 'kV',
#  'EHT set maximum_value': 30.0,
#  'EHT spurious reset_value': False,
#  'EHT tripped_value': False,
#  'EHT_unit': 'kV',
#  'EHT_value': 5.0,
#  'EO Temp Limit_unit': '°C',
#  'EO Temp Limit_value': 35.0,
#  'EO Temp_unit': '°C',
#  'EO Temp_value': 23.9,
#  'EP Aperture_value': 'None fitted',
#  'EP Gas_value': 'Air',
#  'EP Target_unit': 'Pa',
#  'EP Target_value': 10,
#  'EPD High Limit_value': 255,
#  'EPD Low Limit_value': 0,
#  'EPSE Auto Range_value': False,
#  'EPSE Bandwidth_value': 'DC',
#  'EPSE Bias_unit': '%',
#  'EPSE Bias_value': 0.0,
#  'EPSE Electrode_value': 'Ring',
#  'EPSE Gain_value': 'Low',
#  'ESB Grid Max_unit': 'V',
#  'ESB Grid Max_value': 1500,
#  'ESB Grid is_unit': 'V',
#  'ESB Grid is_value': 0,
#  'ESB Grid_unit': 'V',
#  'ESB Grid_value': 0,
#  'ESD Excitation_unit': '%',
#  'ESD Excitation_value': 0.0,
#  'ESD Lower X_unit': '%',
#  'ESD Lower X_value': 0.0,
#  'ESD Lower Y_unit': '%',
#  'ESD Lower Y_value': 0.0,
#  'ESD Upper X_unit': '%',
#  'ESD Upper X_value': 0.0,
#  'ESD Upper Y_unit': '%',
#  'ESD Upper Y_value': 0.0,
#  'Electron Counting_value': False,
#  'Emission Zoom_value': 100,
#  'End Detection_value': False,
#  'Ext I Monitor_unit': 'µA',
#  'Ext I Monitor_value': 280.3,
#  'Ext.Scan Control_value': False,
#  'Extractor Target State_value': False,
#  'Extractor Trip_value': False,
#  'Extractor V Target_unit': 'kV',
#  'Extractor V Target_value': 4.18,
#  'Extractor V_unit': 'kV',
#  'Extractor V_value': 4.18,
#  'FCF Setting_unit': '%',
#  'FCF Setting_value': 0.0,
#  'FCF Tilt Angle_unit': '°',
#  'FCF Tilt Angle_value': 0.0,
#  'FIB Abs Beam Shift X_unit': 'µm',
#  'FIB Abs Beam Shift X_value': 2.48,
#  'FIB Abs Beam Shift Y_unit': 'µm',
#  'FIB Abs Beam Shift Y_value': -2.92,
#  'FIB Aper.Align X_value': 10851,
#  'FIB Aper.Align Y_value': 752,
#  'FIB Aperture X Actual_value': 10851,
#  'FIB Aperture Y Actual_value': 752,
#  'FIB Beam Shift X_unit': 'nm',
#  'FIB Beam Shift X_value': 0.0,
#  'FIB Beam Shift Y_unit': 'nm',
#  'FIB Beam Shift Y_value': 0.0,
#  'FIB Blanked_value': True,
#  'FIB Column Pressure_unit': 'mbar',
#  'FIB Column Pressure_value': 0.0,
#  'FIB Column_value': 'Orsay COBRA',
#  'FIB Condenser actual_unit': 'V',
#  'FIB Condenser actual_value': 25174,
#  'FIB Condenser_unit': 'V',
#  'FIB Condenser_value': 25167,
#  'FIB Drift X_unit': 'nm',
#  'FIB Drift X_value': 0.0,
#  'FIB Drift Y_unit': 'nm',
#  'FIB Drift Y_value': 0.0,
#  'FIB EHT Target_unit': 'kV',
#  'FIB EHT Target_value': 30.0,
#  'FIB EHT_unit': 'kV',
#  'FIB EHT_value': 30.0,
#  'FIB Emission I_unit': 'µA',
#  'FIB Emission I_value': 2.0,
#  'FIB Emission Target_unit': 'µA',
#  'FIB Emission Target_value': 2.0,
#  'FIB Error_value': 'None',
#  'FIB Ext Scan Mode_value': False,
#  'FIB Ext Scan Select_value': 'Ext 0',
#  'FIB External Polarity_value': 0,
#  'FIB Extr.Target_unit': 'kV',
#  'FIB Extr.Target_value': -7.8,
#  'FIB Extractor Conflict_value': False,
#  'FIB Extractor_unit': 'kV',
#  'FIB Extractor_value': -7.78,
#  'FIB Fil Current_unit': 'µA',
#  'FIB Fil Current_value': 0,
#  'FIB Fil I Target_unit': 'µA',
#  'FIB Fil I Target_value': 0,
#  'FIB Fil V target_unit': 'V',
#  'FIB Fil V target_value': 2.0,
#  'FIB Fil Voltage_unit': 'V',
#  'FIB Fil Voltage_value': 0.0,
#  'FIB Focus_value': -0.2,
#  'FIB Gun Pressure_unit': 'mbar',
#  'FIB Gun Pressure_value': 3.73e-08,
#  'FIB Gun State_value': True,
#  'FIB Gun Valve_value': 'Open',
#  'FIB Heating Limit_unit': 'A',
#  'FIB Heating Limit_value': 4.2,
#  'FIB Image Probe_value': '30kV:4nA',
#  'FIB Imaging_value': 'SEM',
#  'FIB Lock Mags_value': False,
#  'FIB Mag Range_value': 0,
#  'FIB Mag fine gain X_value': 0.0,
#  'FIB Mag fine gain Y_value': 0.0,
#  'FIB Mag_value': '1.19 K X',
#  'FIB Milling Probe_value': '30kV:4nA',
#  'FIB Min. Autoheat Current_unit': 'A',
#  'FIB Min. Autoheat Current_value': 2.0,
#  'FIB Mode_value': 'Imaging',
#  'FIB Nudge Step_unit': 'nm',
#  'FIB Nudge Step_value': 100,
#  'FIB Objective Actual_unit': 'V',
#  'FIB Objective Actual_value': 15372,
#  'FIB Objective_unit': 'V',
#  'FIB Objective_value': 15355,
#  'FIB Pixel Size_unit': 'nm',
#  'FIB Pixel Size_value': 93.89,
#  'FIB Present_value': True,
#  'FIB Probe Current Actual_unit': 'pA',
#  'FIB Probe Current Actual_value': 0.0,
#  'FIB Probe_value': '30kV:4nA',
#  'FIB SEM Angle_unit': '°',
#  'FIB SEM Angle_value': 54.0,
#  'FIB Scan Rot_unit': '°',
#  'FIB Scan Rot_value': 0.0,
#  'FIB Scan Size_unit': 'nm',
#  'FIB Scan Size_value': 0.0,
#  'FIB Scan_value': 'Continuous',
#  'FIB Shift Correction X_unit': 'nm',
#  'FIB Shift Correction X_value': 0.0,
#  'FIB Shift Correction Y_unit': 'nm',
#  'FIB Shift Correction Y_value': 0.0,
#  'FIB Source Lifetime_unit': 'µAh',
#  'FIB Source Lifetime_value': 2103.99,
#  'FIB Stig X Centre X_value': 0.0,
#  'FIB Stig X Centre Y_value': 0.0,
#  'FIB Stig X_unit': '%',
#  'FIB Stig X_value': -3.4,
#  'FIB Stig Y Centre X_value': 0.0,
#  'FIB Stig Y Centre Y_value': 0.0,
#  'FIB Stig Y_unit': '%',
#  'FIB Stig Y_value': 4.5,
#  'FIB Suppressor Target_unit': 'V',
#  'FIB Suppressor Target_value': -774,
#  'FIB Suppressor is_value': 'Present',
#  'FIB Suppressor_unit': 'V',
#  'FIB Suppressor_value': -737,
#  'FIB Tilt Comp_unit': '°',
#  'FIB Tilt Comp_value': 0.0,
#  'FIB Track WD Delta_unit': 'nm',
#  'FIB Track WD Delta_value': 0.0,
#  'FIB Tracking WD_value': False,
#  'FIB Wide View_value': False,
#  'FIB Working Distance_unit': 'mm',
#  'FIB Working Distance_value': 0.0,
#  'FIB preparation for pneumatic_value': 'FIB ready for system vent',
#  'Fast Mode_value': False,
#  'Field Mode Angle_unit': '°',
#  'Field Mode Angle_value': -1.0,
#  'Field Mode Orthog_unit': '°',
#  'Field Mode Orthog_value': -1.0,
#  'Field Mode Quadriture_value': 1000,
#  'Field Mode_value': False,
#  'Field Overlap_unit': '%',
#  'Field Overlap_value': 0.0,
#  'Fil I (Usermax)_unit': 'A',
#  'Fil I (Usermax)_value': 4.0,
#  'Fil I Target_unit': 'A',
#  'Fil I Target_value': 2.29,
#  'Fil I_unit': 'A',
#  'Fil I_value': 2.29,
#  'Filament Age_unit': 'Hours',
#  'Filament Age_value': 21151.04,
#  'Filament Type_value': 'FE FEI',
#  'Filament blown_value': False,
#  'File Name_value': 'FeMoOx_AntiA_04_1k5x_CN.tif',
#  'File No_value': 11956,
#  'Final Lens_value': '1500: 68 deg',
#  'Fish-Eye Fitted_value': True,
#  'Fisheye Angle_unit': '°',
#  'Fisheye Angle_value': 168.0,
#  'Fisheye Mode_value': False,
#  'Fisheye Orthog_unit': '°',
#  'Fisheye Orthog_value': 180.0,
#  'Fisheye quadriture_value': 1000,
#  'Flood Gun Actual Mode_value': 'Low Energy Mode',
#  'Flood Gun Blanked_value': False,
#  'Flood Gun Emission Actual_unit': 'µA',
#  'Flood Gun Emission Actual_value': 0.0,
#  'Flood Gun Emission target_unit': 'µA',
#  'Flood Gun Emission target_value': 0.0,
#  'Flood Gun Energy Actual_unit': 'V',
#  'Flood Gun Energy Actual_value': 0.0,
#  'Flood Gun Energy Target_unit': 'V',
#  'Flood Gun Energy Target_value': 0.0,
#  'Flood Gun Extractor Actual State_value': False,
#  'Flood Gun Extractor Voltage_unit': 'V',
#  'Flood Gun Extractor Voltage_value': 0,
#  'Flood Gun Filament Actual_unit': 'µA',
#  'Flood Gun Filament Actual_value': 0,
#  'Flood Gun Filament Target_unit': 'µA',
#  'Flood Gun Filament Target_value': 0,
#  'Flood Gun Fitted_value': False,
#  'Flood Gun Interlock_value': False,
#  'Flood Gun Mode Target_value': 'Low Energy Mode',
#  'Flood Gun Remoting Actual_value': 'Flood Gun Normal',
#  'Flood Gun Serial Number_value': 0,
#  'Flood Gun Status_value': False,
#  'Flood Gun Type_value': 'Flood Gun Unknown Type',
#  'Flood State_value': 'Idle',
#  'Focus Rotation comp._unit': 'kV',
#  'Focus Rotation comp._value': -0.009,
#  'Focus scan max_unit': 'mm',
#  'Focus scan max_value': 40,
#  'Focus scan min_unit': 'mm',
#  'Focus scan min_value': 1,
#  'Focus_unit': 'mm',
#  'Focus_value': 5.1,
#  'Frame Ampl Cal._value': 0,
#  'Frame Counter_value': 45559,
#  'Frame Grabber_value': 'Matrix Titan',
#  'Frames to Int._value': 0,
#  'Frames to average_value': 1,
#  'Free WD_unit': 'mm',
#  'Free WD_value': 5.1,
#  'Freeze Blanks_value': True,
#  'Freeze on_value': 'End Frame',
#  'Freeze_value': 'Idle',
#  'Front Grid_unit': 'V',
#  'Front Grid_value': 0,
#  'GIS Channel with CC_value': 'Channel 1',
#  'GIS Channel_value': 'None',
#  'GIS Heating Status Channel 1_value': 'GIS Not Heating',
#  'GIS Shutdown State_value': 'Normal',
#  'Gain A_unit': '%',
#  'Gain A_value': 100.0,
#  'Gain B_unit': '%',
#  'Gain B_value': 100.0,
#  'Gamma_value': 1.0,
#  'Gemini large beam shift_value': False,
#  'Go to HV @ Shutdown_value': False,
#  'Gun Align X_unit': '%',
#  'Gun Align X_value': 0.0,
#  'Gun Align Y_unit': '%',
#  'Gun Align Y_value': 0.0,
#  'Gun Shift X_unit': '%',
#  'Gun Shift X_value': 0.0,
#  'Gun Shift Y_unit': '%',
#  'Gun Shift Y_value': 0.0,
#  'Gun Tilt X_unit': '%',
#  'Gun Tilt X_value': 0.0,
#  'Gun Tilt Y_unit': '%',
#  'Gun Tilt Y_value': 0.0,
#  'Gun Vacuum_unit': 'mbar',
#  'Gun Vacuum_value': 2.38e-10,
#  'Gun Value at FishEye mode X_unit': '%',
#  'Gun Value at FishEye mode X_value': 0.0,
#  'Gun Value at FishEye mode Y_unit': '%',
#  'Gun Value at FishEye mode Y_value': 0.0,
#  'Gun at X_unit': '%',
#  'Gun at X_value': 17.9,
#  'Gun at Y_unit': '%',
#  'Gun at Y_value': -68.7,
#  'H 10_unit': 'nm',
#  'H 10_value': 0.0,
#  'H 1_unit': 'µm',
#  'H 1_value': 2.052,
#  'H 2_unit': 'µm',
#  'H 2_value': 2.968,
#  'H 3_unit': 'nm',
#  'H 3_value': 0.0,
#  'H 4_unit': 'nm',
#  'H 4_value': 0.0,
#  'H 5_unit': 'nm',
#  'H 5_value': 0.0,
#  'H 6_unit': 'nm',
#  'H 6_value': 0.0,
#  'H 7_unit': 'nm',
#  'H 7_value': 0.0,
#  'H 8_unit': 'nm',
#  'H 8_value': 0.0,
#  'H 9_unit': 'nm',
#  'H 9_value': 0.0,
#  'HE-SE2 Fitted_value': False,
#  'HRRU No._value': 0,
#  'HSync delay_unit': 'ns',
#  'HSync delay_value': 0,
#  'Height_unit': 'µm',
#  'Height_value': 57.16,
#  'High Current_value': True,
#  'High Resolution Mode_value': False,
#  'Holder Diameter_unit': 'mm',
#  'Holder Diameter_value': 50.0,
#  'Holder Height_unit': 'mm',
#  'Holder Height_value': 13.7,
#  'Holder Length_unit': 'mm',
#  'Holder Length_value': 0.0,
#  'Holder Width_unit': 'mm',
#  'Holder Width_value': 0.0,
#  'Humidity Target_unit': '%',
#  'Humidity Target_value': 0.0,
#  'Humidity Valve_value': 'Closed',
#  'Humidity_unit': '%',
#  'Humidity_value': 0.0,
#  'I Probe_unit': 'nA',
#  'I Probe_value': 200.0,
#  'IGP Enabled_value': True,
#  'Image Detect_value': 'Black',
#  'Image Pixel Size_unit': 'nm',
#  'Image Pixel Size_value': 74.43,
#  'Image saved_value': False,
#  'Image_value': 'Frozen',
#  'Images_value': 'd:\\images\\charlotte\\femoox\\femoox_fresh_laser\\laser atlas ct corr\\',
#  'InlensDuo Grid is_unit': 'V',
#  'InlensDuo Grid is_value': 0,
#  'InlensDuo Grid_unit': 'V',
#  'InlensDuo Grid_value': 0,
#  'InlensDuo Mode_value': 'SE',
#  'Input LUT Mode_value': 'Transparent',
#  'Invert A_value': False,
#  'Invert B_value': False,
#  'Jazz Bandwidth_value': 'Low',
#  'Jazz Gain_value': 'Low',
#  'Landing energy_unit': 'kV',
#  'Landing energy_value': 5.0,
#  'Large Beam Shift_value': True,
#  'Laser Illumination_unit': '%',
#  'Laser Illumination_value': 0.0,
#  'Line Avg.Count_value': 2,
#  'Line Counter_value': 767,
#  'Line Scan_value': False,
#  'Line Time_unit': 'ms',
#  'Line Time_value': 126.86,
#  'Line To Frame Lower_value': 0.0,
#  'Line To Frame Upper_value': 0.0,
#  'Line int. count_value': 1,
#  'Line posn X_value': 0,
#  'Line posn Y_value': 192,
#  'Liner Cal @ 10KV_unit': 'V',
#  'Liner Cal @ 10KV_value': 9876,
#  'Liner Target_unit': 'kV',
#  'Liner Target_value': 8.0,
#  'Liner Tube_unit': 'kV',
#  'Liner Tube_value': 7.99,
#  'Liner cal @ 100V_unit': 'V',
#  'Liner cal @ 100V_value': 102,
#  'Low KV Lens_value': 'Absent',
#  'Low Mag Focus_value': 1.0,
#  'Low Mag_value': False,
#  'MGS Evacuation State_value': False,
#  'Mag Cal Actual Height_unit': 'nm',
#  'Mag Cal Actual Height_value': 0.0,
#  'Mag Cal Actual Width_unit': 'nm',
#  'Mag Cal Actual Width_value': 0.0,
#  'Mag Comp. Amplitude_unit': '%',
#  'Mag Comp. Amplitude_value': 37.0,
#  'Mag Comp. Offset_value': 527,
#  'Mag Gain Cal X_value': 1000.0,
#  'Mag Gain Cal Y_value': 1000.0,
#  'Mag Range_value': 2,
#  'Mag Shift Cal X_value': 0.0,
#  'Mag Shift Cal Y_value': 0.0,
#  'Mag State_value': 'calibrated',
#  'Mag Z0_value': 1.0,
#  'Mag Z1_value': 1.0,
#  'Mag scaling decel_value': 1.0,
#  'Mag_value': '1.50 K X',
#  'Mains Sync_value': 'Single Edge',
#  'Max Extractor V_unit': 'kV',
#  'Max Extractor V_value': 4.7,
#  'Mill Item Elapsed Time_unit': 'ms',
#  'Mill Item Elapsed Time_value': 0,
#  'Mill Item Total Time_unit': 'Secs',
#  'Mill Item Total Time_value': 16.02,
#  'Mill List Elapsed Time_unit': 'Mins',
#  'Mill List Elapsed Time_value': 10.1,
#  'Mill List Total Time_unit': 'Mins',
#  'Mill List Total Time_value': 10.1,
#  'Min Extractor V_unit': 'kV',
#  'Min Extractor V_value': 3.0,
#  'Min Mag_unit': 'X',
#  'Min Mag_value': 24,
#  'Mix Signal_value': 0.0,
#  'Mixing_value': False,
#  'Monitor_value': '19/21 inch',
#  'Nano Tips_value': 'Absent',
#  'New Filament_value': False,
#  'Noise Reduction_value': 'Line Avg',
#  'Noise reduction for fast scanspeeds_value': False,
#  'Nominal Fil I_unit': 'A',
#  'Nominal Fil I_value': 2.29,
#  'Nominal extractor V_unit': 'kV',
#  'Nominal extractor V_value': 4.18,
#  'Num. Regions_value': 0,
#  'Offset A_unit': '%',
#  'Offset A_value': 0.0,
#  'Offset B_unit': '%',
#  'Offset B_value': 0.0,
#  'Operating Mode_value': 'Normal',
#  'Opt. Semi Angle_unit': 'µrad',
#  'Opt. Semi Angle_value': 0.0,
#  'Opt.Aperture_value': 2,
#  'OptiBeam Is_value': False,
#  'OptiBeam Mode_value': 'Resolution',
#  'OptiBeam Res Mode_value': 'manual',
#  'OptiBeam conjugate_value': False,
#  'OptiBeam_value': False,
#  'OptiProbe_value': False,
#  'Orthogonality Lower_unit': '°',
#  'Orthogonality Lower_value': 0.0,
#  'Orthogonality Upper_unit': '°',
#  'Orthogonality Upper_value': 0.0,
#  'Output Reduction_value': 1,
#  'Output To_value': 'Display/File',
#  'Output dev_value': '19/21 inch display',
#  'Pa 10_unit': 'nm',
#  'Pa 10_value': 0.0,
#  'Pa 1_unit': 'nm',
#  'Pa 1_value': 124.8,
#  'Pa 2_unit': 'nm',
#  'Pa 2_value': 0.0,
#  'Pa 3_unit': 'nm',
#  'Pa 3_value': 0.0,
#  'Pa 4_unit': 'nm',
#  'Pa 4_value': 0.0,
#  'Pa 5_unit': 'nm',
#  'Pa 5_value': 0.0,
#  'Pa 6_unit': 'nm',
#  'Pa 6_value': 0.0,
#  'Pa 7_unit': 'nm',
#  'Pa 7_value': 0.0,
#  'Pa 8_unit': 'nm',
#  'Pa 8_value': 0.0,
#  'Pa 9_unit': 'nm',
#  'Pa 9_value': 0.0,
#  'Partial Vent on Standby_value': False,
#  'Pb 1_unit': '°',
#  'Pb 1_value': 1.2,
#  'Pb 2_unit': '°',
#  'Pb 2_value': 0.0,
#  'Pb 3_unit': '°',
#  'Pb 3_value': 0.0,
#  'Pb 4_unit': '°',
#  'Pb 4_value': 0.0,
#  'Pb 5_unit': '°',
#  'Pb 5_value': 0.0,
#  'Pb 6_unit': '°',
#  'Pb 6_value': 0.0,
#  'Pb 7_unit': '°',
#  'Pb 7_value': 0.0,
#  'Peltier Photo_value': False,
#  'Peltier Target_unit': '°C',
#  'Peltier Target_value': 20.0,
#  'Peltier Temp_unit': '°C',
#  'Peltier Temp_value': 20.0,
#  'Peltier Type_value': 'Deben',
#  'Peltier_value': False,
#  'Photo No._value': 30556,
#  'Piezo Exchange X_unit': 'µm',
#  'Piezo Exchange X_value': 0.0,
#  'Piezo Exchange Y_unit': 'µm',
#  'Piezo Exchange Y_value': 0.0,
#  'Piezo Goto X_unit': 'µm',
#  'Piezo Goto X_value': 0.0,
#  'Piezo Goto Y_unit': 'µm',
#  'Piezo Goto Y_value': 0.0,
#  'Piezo at X_unit': 'µm',
#  'Piezo at X_value': 0.0,
#  'Piezo at Y_unit': 'µm',
#  'Piezo at Y_value': 0.0,
#  'Pirani Pressure_unit': 'mbar',
#  'Pirani Pressure_value': 0.0,
#  'Pix Size state_value': 'calibrated',
#  'Pixel Size_unit': 'nm',
#  'Pixel Size_value': 74.43,
#  'Pneumatic Device in use_value': 'None',
#  'Print No._value': 0,
#  'Probe Cal Factor_value': 1.0,
#  'Profile 1 X1_value': 0,
#  'Profile 1 X2_value': 0,
#  'Profile 2 X1_value': 0,
#  'Profile 2 X2_value': 0,
#  'Profile Top_value': 300,
#  'Profile Width 1_unit': 'nm',
#  'Profile Width 1_value': 0.0,
#  'Profile Width 2_unit': 'nm',
#  'Profile Width 2_value': 0.0,
#  'Profile width_unit': 'nm',
#  'Profile width_value': 0.0,
#  'Purge Max_unit': 'Pa',
#  'Purge Max_value': 1066,
#  'Purge Min_unit': 'Pa',
#  'Purge Min_value': 133,
#  'Purge cycles_value': 2,
#  'Q1_value': 'Normal',
#  'Q2_value': 'Normal',
#  'Q3_value': 'Normal',
#  'Q4_value': 'Normal',
#  'Q5_value': False,
#  'Recipe_value': 'Idle',
#  'Red.Raster Height_value': 247,
#  'Red.Raster Posn X_value': 208,
#  'Red.Raster Posn Y_value': 336,
#  'Red.Raster Width_value': 336,
#  'Reduced Raster Width_value': 512,
#  'Reduced Raster Y_value': 192,
#  'Reference Mag_value': 'Polaroid 545',
#  'Remoting Target_value': 'Flood Gun Normal',
#  'Right Frozen_value': True,
#  'SCD Auto Range_value': False,
#  'SCD Bandwidth_value': 'DC',
#  'SCD Gain_value': 'Low',
#  'SCM Status_value': False,
#  'SCM range_value': '3->10 pA',
#  'SEM Level @_unit': '°',
#  'SEM Level @_value': 0.0,
#  'SESI Mode_value': 'Ion',
#  'SI source-hidden_value': 0,
#  'STEM Auto_value': False,
#  'STEM Fast_value': False,
#  'STEM Gain_value': 'Medium',
#  'STEM Q1_value': False,
#  'STEM Q2_value': False,
#  'STEM Q3_value': False,
#  'STEM Q4_value': False,
#  'STEM Q5_value': False,
#  'STEM Seg. Mode_value': False,
#  'Safe STEM Valid_value': True,
#  'Sample Holder_value': 'Carousel 8x6.5mm',
#  'Sample at X_value': 0.0,
#  'Sample at Y_value': 0.0,
#  'Saturate at_value': 'Second peak',
#  'Scan Gen_value': 'Present',
#  'Scan Offset X_value': 0,
#  'Scan Offset Y_value': 0,
#  'Scan Orth corrn_unit': '°',
#  'Scan Orth corrn_value': 0.3,
#  'Scan Orthog_value': True,
#  'Scan Rot_value': False,
#  'Scan Rotation Offset Lower_unit': '°',
#  'Scan Rotation Offset Lower_value': 0.0,
#  'Scan Rotation_unit': '°',
#  'Scan Rotation_value': 0.0,
#  'Scan Speed_value': 10,
#  'Scan X cal._value': 0,
#  'Scan Y cal._value': 0,
#  'ScanGen Type_value': 'L-REM',
#  'Scint._value': True,
#  'Sem drift status_value': 'No Reference',
#  'Sem_value': 'Auriga 60',
#  'Semi Angle_unit': 'µrad',
#  'Semi Angle_value': 0.0,
#  'Serial No._value': 'Auriga 60-46-18',
#  'Shift Amp Lower Gain X_value': 0.0,
#  'Shift Amp Lower Gain Y_value': 0.0,
#  'Shift Amp Lower Offset X_value': 0.0,
#  'Shift Amp Lower Offset Y_value': 0.0,
#  'Shift Amp Upper Gain X_value': 0.0,
#  'Shift Amp Upper Gain Y_value': 0.0,
#  'Shift Amp Upper Offset X_value': 0.0,
#  'Shift Amp Upper Offset Y_value': 0.0,
#  'Signal A Z0_value': 'InLens',
#  'Signal A Z1_value': 'InLens',
#  'Signal A Z2_value': 'InLens',
#  'Signal A Z3_value': 'InLens',
#  'Signal A_value': 'InLens',
#  'Signal B_value': 'InLens',
#  'Signal_value': 1.0,
#  'Slice Angle_unit': '°',
#  'Slice Angle_value': 0.0,
#  'Slice Height_unit': 'nm',
#  'Slice Height_value': 300.0,
#  'Slice Index_value': -1,
#  'Slice Width_unit': 'µm',
#  'Slice Width_value': 25.63,
#  'Slice X_unit': 'µm',
#  'Slice X_value': -9.34,
#  'Slice Y_unit': 'µm',
#  'Slice Y_value': -13.53,
#  'SmartImage Contrast_unit': '%',
#  'SmartImage Contrast_value': 0.0,
#  'SmartImage Noise Reduction_value': False,
#  'SmartImage Sharpening_unit': '%',
#  'SmartImage Sharpening_value': 0.0,
#  'SmartImage Threshold_unit': '%',
#  'SmartImage Threshold_value': 0.0,
#  'SmartImage Topography_unit': '%',
#  'SmartImage Topography_value': 0.0,
#  'Spacer Thickness_unit': 'mm',
#  'Spacer Thickness_value': 0.0,
#  'Specimen Diameter_unit': 'mm',
#  'Specimen Diameter_value': 10,
#  'Specimen Height_unit': 'mm',
#  'Specimen Height_value': 0,
#  'Specimen I_unit': 'pA',
#  'Specimen I_value': 0.0,
#  'Spot Size_value': 1,
#  'Spot X Cal_value': 0,
#  'Spot at X_value': 256,
#  'Spot at Y_value': 192,
#  'Spot signal_value': 0,
#  'Spot_value': False,
#  'Stage Angle corrn._value': True,
#  'Stage Angle_unit': '°',
#  'Stage Angle_value': 178.1,
#  'Stage Centre X_unit': 'mm',
#  'Stage Centre X_value': 76.311,
#  'Stage Centre Y_unit': 'mm',
#  'Stage Centre Y_value': 75.755,
#  'Stage Delta M_unit': 'mm',
#  'Stage Delta M_value': 0.0,
#  'Stage Delta R_unit': '°',
#  'Stage Delta R_value': 180.0,
#  'Stage Delta T_unit': '°',
#  'Stage Delta T_value': 1.0,
#  'Stage Delta X_unit': 'mm',
#  'Stage Delta X_value': 0.0,
#  'Stage Delta Y_unit': 'mm',
#  'Stage Delta Y_value': 0.0,
#  'Stage Delta Z_unit': 'mm',
#  'Stage Delta Z_value': 0.0,
#  'Stage Initialised_value': True,
#  'Stage Is_value': 'Idle',
#  'Stage Tilt_value': 'in X',
#  'Stage Tilted_value': True,
#  'Stage Vector M_unit': '%',
#  'Stage Vector M_value': 0.0,
#  'Stage X+M Angle_unit': '°',
#  'Stage X+M Angle_value': 8.0,
#  'Stage X+M Rotation_unit': '°',
#  'Stage X+M Rotation_value': 0.0,
#  'Stage at M_unit': 'mm',
#  'Stage at M_value': 6.292,
#  'Stage at R_unit': '°',
#  'Stage at R_value': 46.8,
#  'Stage at T_unit': '°',
#  'Stage at T_value': 54.0,
#  'Stage at X_unit': 'mm',
#  'Stage at X_value': 74.8291,
#  'Stage at Y_unit': 'mm',
#  'Stage at Y_value': 71.5701,
#  'Stage at Z_unit': 'mm',
#  'Stage at Z_value': 41.835,
#  'Stage at field X_value': 1,
#  'Stage at field Y_value': 1,
#  'Stage bias Low Volts_unit': 'V',
#  'Stage bias Low Volts_value': 0.0,
#  'Stage bias low voltage_value': False,
#  'Stage bias mode_value': 'contrast mode',
#  'Stage bias wobble amplitude_unit': 'V',
#  'Stage bias wobble amplitude_value': 0,
#  'Stage comms fail_value': False,
#  ...}

# %% [markdown]
# Load the schema:

# %%
mySchema = "SEM_schema.json"

with open(mySchema, 'r') as f:
    jsonSchema = json.load(f)
    
readSchema = MetadataSchemaReader(jsonSchema)

schema = readSchema.searchedSchema

# %% [markdown]
# Load the map:

# %%
with open('new_mapSEM.json', 'r') as m:
    newmapSEM = json.load(m)

# %% [markdown]
# Copy the metadata dictionary containing the key-value pairs to be edited:

# %%
metadataDict = copy.deepcopy(resultDictionary_filtered_sorted)

# %% [markdown]
# Map the terms using `attributeMapping()`:

# %%
Map = AttributeMapping(metadataDict, newmapSEM, 'mappedTerms')
workingDict = Map.__dict__

# %% [markdown]
# Define a function to clean up the data in the format adhering to the schema:

# %%
def cleanData(mappedDict):
    # Make endTime var as ISO 8601
    endTime = mappedDict['entry.endTime.Date'] + ' ' + mappedDict['entry.endTime.Time']
    mappedDict['entry.endTime'] = parser.parse(endTime).isoformat()
    
    # Remove separate date and time vars
    mappedDict.pop('entry.endTime.Date')
    mappedDict.pop('entry.endTime.Time')
    logging.info('Correctly fixed Date')
    
    # Split pixel sizes into x and y
    imgSize = [float(s.strip()) for s in mappedDict['entry.instrument.imaging.numberOfPixels.xPixels'].split('*')]
    mappedDict['entry.instrument.imaging.numberOfPixels.xPixels'] = imgSize[0]
    mappedDict['entry.instrument.imaging.numberOfPixels.yPixels'] = imgSize[1]
    logging.info('Correctly fixed x and y pixels')
    
    # Format tilt correction
    
    tiltCorr = mappedDict['entry.instrument.imaging.tiltCorrection']
    if tiltCorr: 
        mappedDict['entry.instrument.imaging.tiltCorrection'] = ''
    else:
        mappedDict['entry.instrument.imaging.tiltCorrection'] = 'None'
    logging.info('Correctly fixed tiltCorr')
        
    # Deg symbol to "degree"
      
    return {key: value for key, value in sorted(mappedDict.items())}

# %% [markdown]
# Define a function to "walk" the nested dict schema and replace the values with their key-value pairs

# %%
def modVal(dic, keys, val):
    for key in keys[:-1]:
        dic = dic.setdefault(key, {})
    dic[keys[-1]] = val
    return None

# if complete path in Nicolas' mapping file, will this func work as well?

# %% [markdown]
# Define a function that takes the input file and returns an output file:

# %%
def workFlow(sourceImg, schema, mapSEM, resultsPath):
    src = sourceImg
    md = zm.zeiss_meta(src)
    del md[0]
    resultDictionary = {**dict((x1+"_value",x2) for x0, x1, x2, x3 in md) , **dict((x1+"_unit",x3) for x0, x1, x2, x3 in md)}
    resultDictionary_filtered = {k: v for k, v in resultDictionary.items() if v != ''}
    metadataDict = dict(sorted(resultDictionary_filtered.items()))
    
    # Open and load schema
    with open(mySchema, 'r') as f:
        jsonSchema = json.load(f)
    
    readSchema = MetadataSchemaReader(jsonSchema)
    schema = readSchema.searchedSchema
    
    # Open and load map
    with open(mapSEM, 'r') as m:
        newmapSEM = json.load(m)
        
    # Map the metadata dictionary
    Map = AttributeMapping(metadataDict, newmapSEM, 'mappedTerms')
    workingDict = Map.__dict__
    
    # Clean up the metadata
    cleanDict = cleanData(workingDict)
        
    # Modify schema file
    outputFile = dict()
    for i, key in enumerate(cleanDict):
        modVal(outputFile, key.split('.'), cleanDict[key])
        
    # Output file to .json
    outputFilename = os.path.join(resultsPath, os.path.basename(src[:-4] + '.json'))
#     outputFilename = os.path.join(resultsPath, src[:-4] + '.json')
    with open(outputFilename, 'w') as f:
        json.dump(outputFile, f)
        
    return outputFile

# %%
# imgDir = '/Users/elias/matwerk/sem-mapping/SEM_TIFF_images/'
# resultsPath = '/Users/elias/matwerk/sem-mapping/results'

# pprint(workFlow('FeMoOx_AntiA_04_1k5x_CN.tif', mySchema, myMap, resultsPath))

# %%
mySchema  = "SEM_schema.json"
myMap       = 'new_mapSEM.json'
imgDir      = '/Users/elias/Documents/SEM_Mapping_Tool/sem-mapping/test_images/DifferentDetector'
resultsPath =  '/Users/elias/Documents/SEM_Mapping_Tool/sem-mapping/results'

for file in os.listdir(imgDir):
    if file.endswith(".tif"):
        workFlow(os.path.join(imgDir, file), mySchema, myMap, resultsPath)
